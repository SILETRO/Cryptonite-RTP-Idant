# %%
import cv2
import pandas as pd
import numpy as np
import imageio
import os
from IPython.display import Image, display

# %%
vs = cv2.VideoCapture('volleyball_match.mp4')

# %%
MIN_AREA = 200 
MAX_AREA = 900

fgbg = cv2.createBackgroundSubtractorMOG2(history=20, varThreshold=50, detectShadows=True)

trajectory = []        
max_points = 2     

while True:
    ret, frame = vs.read()
    if not ret:
        break

    fgmask = fgbg.apply(frame)

    _, fgmask = cv2.threshold(fgmask, 250, 255, cv2.THRESH_BINARY)

    fgmask = cv2.erode(fgmask, None, iterations=1)
    fgmask = cv2.dilate(fgmask, None, iterations=2)

    cnts, _ = cv2.findContours(
        fgmask.copy(),
        cv2.RETR_EXTERNAL,
        cv2.CHAIN_APPROX_SIMPLE
    )
    
    ball_candidate = None

    for c in cnts:
        area = cv2.contourArea(c)
        
        if area < MIN_AREA or area > MAX_AREA:
            continue
            
        x, y, w, h = cv2.boundingRect(c)
        aspect_ratio = float(w) / h
        
        if aspect_ratio < 0.7 or aspect_ratio > 1.5:
            continue

        perimeter = cv2.arcLength(c, True)
        if perimeter == 0:
            continue

        circularity = (4 * np.pi * area) / (perimeter ** 2)
        if circularity < 0.7:
            continue

        cx = int(x + w/2)
        cy = int(y + h/2)
        r  = int(w/2)

        ball_candidate = (cx, cy, r)

        trajectory.append((cx, cy))

        if len(trajectory) > max_points:
            trajectory.pop(0)

        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, "Ball", (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


    for i in range(1, len(trajectory)):
        x1, y1 = trajectory[i - 1]
        x2, y2 = trajectory[i]

        cv2.line(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)

    cv2.imshow("Detect", frame)

    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

vs.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 73
#      69         cv2.line(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
#      71     cv2.imshow("Detect", frame)
# ---> 73     if cv2.waitKey(20) & 0xFF == ord('q'):
#      74         break
#      76 vs.release()
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
from ultralytics import YOLO

VIDEO_PATH = 'volleyball_match.mp4'
MODEL_SIZE = 'yolov8n.pt'

NET_Y_LEVEL = 420 

model = YOLO(MODEL_SIZE)

court_polygon = np.array([
    [300, 275],   # Top-Left
    [980, 263],   # Top-Right
    [1250, 700],  # Bottom-Right 
    [75, 700]     # Bottom-Left
], np.int32)

cap = cv2.VideoCapture(VIDEO_PATH)

while True:
    ret, frame = cap.read()
    if not ret: break

    height, width, _ = frame.shape
    
    results = model.predict(frame, conf=0.3, classes=[0], verbose=False)
    boxes = results[0].boxes

    far_team_count = 0 
    near_team_count = 0 

    cv2.polylines(frame, [court_polygon], isClosed=True, color=(255, 255, 0), thickness=2)
    
    cv2.line(frame, (0, NET_Y_LEVEL), (width, NET_Y_LEVEL), (255, 255, 255), 2)

    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
        
        feet_x = int((x1 + x2) / 2)
        feet_y = int(y2)

        is_inside = cv2.pointPolygonTest(court_polygon, (feet_x, feet_y), False)

        if is_inside >= 0:

            if feet_y < NET_Y_LEVEL:
                far_team_count += 1
                color = (0, 255, 255) # Yellow Box
                label = "Far"
            else:

                near_team_count += 1
                color = (0, 0, 255) # Red Box
                label = "Near"
            

            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

    overlay = frame.copy()
    cv2.rectangle(overlay, (0, 0), (width, 80), (0, 0, 0), -1)
    frame = cv2.addWeighted(overlay, 0.4, frame, 0.6, 0)

    cv2.putText(frame, f"Far Team: {far_team_count}", (50, 50), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
    
    cv2.putText(frame, f"Near Team: {near_team_count}", (width - 350, 50), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    cv2.imshow("Team Counter", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 27
#      23 if not ret: break
#      25 height, width, _ = frame.shape
# ---> 27 results = model.predict(frame, conf=0.3, classes=[0], verbose=False)
#      28 boxes = results[0].boxes
#      30 far_team_count = 0
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/engine/model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/engine/predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/nn/autobackend.py:717, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     715 # PyTorch
#     716 if self.pt or self.nn_module:
# --> 717     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     719 # TorchScript
#     720 elif self.jit:
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/nn/tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/nn/tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/ultralytics/nn/tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/modules/upsampling.py:174, in Upsample.forward(self, input)
#     170 def forward(self, input: Tensor) -> Tensor:
#     171     """
#     172     Runs the forward pass.
#     173     """
# --> 174     return F.interpolate(
#     175         input,
#     176         self.size,
#     177         self.scale_factor,
#     178         self.mode,
#     179         self.align_corners,
#     180         recompute_scale_factor=self.recompute_scale_factor,
#     181     )
#
# File ~/Developer/ML Basics/mlbase/lib/python3.13/site-packages/torch/nn/functional.py:4812, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4809     return torch._C._nn.upsample_nearest1d(input, output_size, scale_factors)
#    4810 if input.dim() == 4 and mode == "nearest":
#    4811     # pyrefly: ignore [bad-argument-type]
# -> 4812     return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
#    4813 if input.dim() == 5 and mode == "nearest":
#    4814     # pyrefly: ignore [bad-argument-type]
#    4815     return torch._C._nn.upsample_nearest3d(input, output_size, scale_factors)
#
# KeyboardInterrupt:
